# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mendeleev as mn
from mendeleev import element
import xlrd
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/afridshirsekar/opt/anaconda3/lib/python3.8/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
compositions_50 = pd.read_excel('/Users/afridshirsekar/Desktop/graphnet scripts/Composition_Ti_family-50percent.xls')
Nan_rows = compositions_50.loc[compositions_50['bandgap'] == 'Nan'].index
neg_rows = compositions_50.loc[compositions_50['bandgap'] < 0].index
compositions_50 = compositions_50.drop(labels=Nan_rows, axis= 'index')
compositions_50 = compositions_50.drop(labels=neg_rows, axis= 'index')

# %%
compositions_random = pd.read_excel('/Users/afridshirsekar/Desktop/graphnet scripts/Compositions_new_elements_no_summary.xls')
Nan_rows = compositions_random.loc[compositions_random['bandgap'] == 'Nan'].index
#neg_rows = compositions_random.loc[compositions_random['bandgap'] < 0].index
compositions_random = compositions_random.drop(labels=Nan_rows, axis= 'index')
#compositions_random = compositions_random.drop(labels=neg_rows, axis= 'index')

# %%
compositions_random_new = compositions_random.filter(['formula', 'site1', 'site2', 'site3', 'site4', 'site5', 'site6', 'site7', 'site8', 'bandgap'], axis = 1)
compositions_50_new = compositions_50.filter(['formula', 'site1', 'site2', 'site3', 'site4', 'site5', 'site6', 'site7', 'site8', 'bandgap'], axis = 1)

# %%
compositions_1000 = compositions_random_new.append(compositions_50_new, ignore_index=True)
compositions_1000.to_excel('/Users/afridshirsekar/Desktop/graphnet scripts/Compositions_1000.xls')

# %%
compositions_test_old_structures = pd.read_excel('/Users/afridshirsekar/Desktop/graphnet scripts/Compositions_1000.xls')
Nan_rows = compositions_test_old_structures.loc[compositions_test_old_structures['bandgap'] == 'Nan'].index
neg_rows = compositions_test_old_structures.loc[compositions_test_old_structures['bandgap'] < 0].index
compositions_Ti_family = compositions_test_old_structures.drop(labels=Nan_rows, axis= 'index')
compositions_Ti_family = compositions_test_old_structures.drop(labels=neg_rows, axis= 'index')

# %%
print(compositions_Ti_family)
#map elements to mendeleev object
Ba = mn.element('Ba')
Sr = mn.element('Sr')
Ca = mn.element('Ca')
Pb = mn.element('Pb')
Ti = mn.element('Ti')
Al = mn.element('Al')
Zr = mn.element('Zr')
V  = mn.element('V')
Hf = mn.element('Hf')
Nb = mn.element('Nb')
Si = mn.element('Si')
Sc = mn.element('Sc')
Sb = mn.element('Sb')
Ta = mn.element('Ta')
Mg = mn.element('Mg')
O  = mn.element('O')
Cs = mn.element('Cs')
Rb = mn.element('Rb')
K  = mn.element('K') 
Na = mn.element('Na')
Li = mn.element('Li')
Y  = mn.element('Y')





elenega = {'Ba' : Ba.en_pauling, 'Sr' : Sr.en_pauling, 'Ca' : Ca.en_pauling, 'Pb' : Pb.en_pauling, 'Ti' : Ti.en_pauling , 'Al' : Al.en_pauling, 'Zr' : Zr.en_pauling, 'V' : V.en_pauling, 'Hf' : Hf.en_pauling, 'Nb' : Nb.en_pauling, 'Si' : Si.en_pauling, 'Sc' : Sc.en_pauling, 'Sb' : Sb.en_pauling, 'Ta' : Ta.en_pauling, 'Mg' : Mg.en_pauling, 'O' : O.en_pauling, 'Cs' : Cs.en_pauling, 'Rb' : Rb.en_pauling, 'K' : K.en_pauling, 'Na' : Na.en_pauling, 'Li' : Li.en_pauling, 'Y' : Y.en_pauling }

eleaff = {'Ba' : Ba.electron_affinity, 'Sr' : Sr.electron_affinity, 'Ca' : Ca.electron_affinity, 'Pb' : Pb.electron_affinity, 'Ti' : Ti.electron_affinity , 'Al' : Al.electron_affinity, 'Zr' : Zr.electron_affinity, 'V' : V.electron_affinity, 'Hf' : Hf.electron_affinity, 'Nb' : Nb.electron_affinity, 'Si' : Si.electron_affinity, 'Sc' : Sc.electron_affinity, 'Sb' : Sb.electron_affinity, 'Ta' : Ta.electron_affinity, 'Mg' : 0, 'O' : O.electron_affinity, 'Cs' : Cs.electron_affinity, 'Rb' : Rb.electron_affinity, 'K' : K.electron_affinity, 'Na' : Na.electron_affinity, 'Li' : Li.electron_affinity, 'Y' : Y.electron_affinity}

ioniz1 = {'Ba' : Ba.ionenergies[1] * 96.49, 'Ca' : Ca.ionenergies[1] * 96.49, 'Sr' : Sr.ionenergies[1] * 96.49, 'Pb' : Pb.ionenergies[1] * 96.49, 'Ti' : Ti.ionenergies[1] * 96.49, 'Al' : Al.ionenergies[1] * 96.49, 'Zr' : Zr.ionenergies[1] * 96.49, 'V' : V.ionenergies[1] * 96.49, 'Hf' : Hf.ionenergies[1] * 96.49, 'Nb' : Nb.ionenergies[1] * 96.49, 'Si' : Si.ionenergies[1] * 96.49, 'Sc' : Sc.ionenergies[1] * 96.49, 'Sb' : Sb.ionenergies[1] * 96.49, 'Ta' : Ta.ionenergies[1] * 96.49, 'Mg' : Mg.ionenergies[1] * 96.49, 'O' : O.ionenergies[1] * 96.49, 'Cs' : Cs.ionenergies[1] * 96.49, 'Rb' : Rb.ionenergies[1] * 96.49, 'K' : K.ionenergies[1] * 96.49, 'Na' : Na.ionenergies[1] * 96.49, 'Li' : Li.ionenergies[1] * 96.49, 'Y' : Y.ionenergies[1] * 96.49 }

ioniz2 = {'Ba' : Ba.ionenergies[2] * 96.49, 'Ca' : Ca.ionenergies[2] * 96.49, 'Sr' : Sr.ionenergies[2] * 96.49, 'Pb' : Pb.ionenergies[2] * 96.49, 'Ti' : Ti.ionenergies[2] * 96.49, 'Al' : Al.ionenergies[2] * 96.49, 'Zr' : Zr.ionenergies[2] * 96.49, 'V' : V.ionenergies[2] * 96.49, 'Hf' : Hf.ionenergies[2] * 96.49, 'Nb' : Nb.ionenergies[2] * 96.49, 'Si' : Si.ionenergies[2] * 96.49, 'Sc' : Sc.ionenergies[2] * 96.49, 'Sb' : Sb.ionenergies[2] * 96.49, 'Ta' : Ta.ionenergies[2] * 96.49, 'Mg' : Mg.ionenergies[2] * 96.49, 'O' : O.ionenergies[2] * 96.49, 'Cs' : Cs.ionenergies[2] * 96.49, 'Rb' : Rb.ionenergies[2] * 96.49, 'K' : K.ionenergies[2] * 96.49, 'Na' : Na.ionenergies[2] * 96.49, 'Li' : Li.ionenergies[2] * 96.49, 'Y' : Y.ionenergies[2] * 96.49 }

ioniz3 = {'Ba' : Ba.ionenergies[3] * 96.49, 'Ca' : Ca.ionenergies[3] * 96.49, 'Sr' : Sr.ionenergies[3] * 96.49, 'Pb' : Pb.ionenergies[3] * 96.49, 'Ti' : Ti.ionenergies[3] * 96.49, 'Al' : Al.ionenergies[3] * 96.49, 'Zr' : Zr.ionenergies[3] * 96.49, 'V' : V.ionenergies[3] * 96.49, 'Hf' : Hf.ionenergies[3] * 96.49, 'Nb' : Nb.ionenergies[3] * 96.49, 'Si' : Si.ionenergies[3] * 96.49, 'Sc' : Sc.ionenergies[3] * 96.49, 'Sb' : Sb.ionenergies[3] * 96.49, 'Ta' : Ta.ionenergies[3] * 96.49, 'Mg' : Mg.ionenergies[3] * 96.49, 'O' : O.ionenergies[3] * 96.49, 'Cs' : Cs.ionenergies[3] * 96.49, 'Rb' : Rb.ionenergies[3] * 96.49, 'K' : K.ionenergies[3] * 96.49, 'Na' : Na.ionenergies[3] * 96.49, 'Li' : Li.ionenergies[3] * 96.49, 'Y' : Y.ionenergies[3] * 96.49 }

ioniz4 = {'Ba' : Ba.ionenergies[4] * 96.49, 'Ca' : Ca.ionenergies[4] * 96.49, 'Sr' : Sr.ionenergies[4] * 96.49, 'Pb' : Pb.ionenergies[4] * 96.49, 'Ti' : Ti.ionenergies[4] * 96.49, 'Al' : Al.ionenergies[4] * 96.49, 'Zr' : Zr.ionenergies[4] * 96.49, 'V' : V.ionenergies[4] * 96.49, 'Hf' : Hf.ionenergies[4] * 96.49, 'Nb' : Nb.ionenergies[4] * 96.49, 'Si' : Si.ionenergies[4] * 96.49, 'Sc' : Sc.ionenergies[4] * 96.49, 'Sb' : Sb.ionenergies[4] * 96.49, 'Ta' : Ta.ionenergies[4] * 96.49, 'Mg' : Mg.ionenergies[4] * 96.49, 'O' : O.ionenergies[4] * 96.49, 'Cs' : Cs.ionenergies[4] * 96.49, 'Rb' : Rb.ionenergies[4] * 96.49, 'K' : K.ionenergies[4] * 96.49, 'Na' : Na.ionenergies[4] * 96.49, 'Li' : Li.ionenergies[3] * 96.49, 'Y' : Y.ionenergies[4] * 96.49 }

ioniz5 = {'Ba' : Ba.ionenergies[5] * 96.49, 'Ca' : Ca.ionenergies[5] * 96.49, 'Sr' : Sr.ionenergies[5] * 96.49, 'Pb' : Pb.ionenergies[5] * 96.49, 'Ti' : Ti.ionenergies[5] * 96.49, 'Al' : Al.ionenergies[5] * 96.49, 'Zr' : Zr.ionenergies[5] * 96.49, 'V' : V.ionenergies[5] * 96.49, 'Hf' : Hf.ionenergies[5] * 96.49, 'Nb' : Nb.ionenergies[5] * 96.49, 'Si' : Si.ionenergies[5] * 96.49, 'Sc' : Sc.ionenergies[5] * 96.49, 'Sb' : Sb.ionenergies[5] * 96.49, 'Ta' : Ta.ionenergies[5] * 96.49, 'Mg' : Mg.ionenergies[5] * 96.49, 'O' : O.ionenergies[5] * 96.49, 'Cs' : Cs.ionenergies[5] * 96.49, 'Rb' : Rb.ionenergies[5] * 96.49, 'K' : K.ionenergies[5] * 96.49, 'Na' : Na.ionenergies[5] * 96.49, 'Li' : Li.ionenergies[3] * 96.49, 'Y' : Y.ionenergies[5] * 96.49 }

ioniz6 = {'Ba' : Ba.ionenergies[6] * 96.49, 'Ca' : Ca.ionenergies[6] * 96.49, 'Sr' : Sr.ionenergies[6] * 96.49, 'Pb' : Pb.ionenergies[6] * 96.49, 'Ti' : Ti.ionenergies[6] * 96.49, 'Al' : Al.ionenergies[6] * 96.49, 'Zr' : Zr.ionenergies[6] * 96.49, 'V' : V.ionenergies[6] * 96.49, 'Hf' : Hf.ionenergies[6] * 96.49, 'Nb' : Nb.ionenergies[6] * 96.49, 'Si' : Si.ionenergies[6] * 96.49, 'Sc' : Sc.ionenergies[6] * 96.49, 'Sb' : Sb.ionenergies[6] * 96.49, 'Ta' : Ta.ionenergies[6] * 96.49, 'Mg' : Mg.ionenergies[6] * 96.49, 'O' : O.ionenergies[6] * 96.49, 'Cs' : Cs.ionenergies[6] * 96.49, 'Rb' : Rb.ionenergies[6] * 96.49, 'K' : K.ionenergies[6] * 96.49, 'Na' : Na.ionenergies[6] * 96.49, 'Li' : Li.ionenergies[3] * 96.49, 'Y' : Y.ionenergies[6] * 96.49 }

orb_rad_rs = {'Ba' : 4.44826, 'Ca' : 3.47565, 'Sr' : 3.86364, 'Pb' : 2.29029, 'Ti' : 3.06434, 'Zr' : 3.37293, 'Al' : 2.09800, 'V': 2.91775, 'Si' : 1.79642, 'Sc' : 3.24169, 'Sb' : 2.01336, 'Ta' : 3.22942, 'Mg' : 2.58617, 'O' : 0.879462, 'Cs' : 5.33704, 'Rb' : 4.706161, 'K' : 4.34528, 'Na' : 3.39059, 'Li' : 3.10010, 'Y' : 3.57338 }

orb_rad_rp = {'Ba' : 0, 'Ca' : 0, 'Sr' : 0, 'Pb' : 2.80073, 'Ti' : 0, 'Zr' : 0, 'Al' : 2.68675, 'V' : 0, 'Si' : 2.17544, 'Sc' : 0, 'Sb' : 2.39286, 'Ta' : 0, 'Mg' : 0, 'O' : 0.832845, 'Cs' : 0, 'Rb' : 0, 'K' : 0, 'Na' : 0, 'Li' : 0, 'Y' : 0 }

orb_rad_rd = {'Ba' : 0, 'Ca' : 0, 'Sr' : 0, 'Pb' : 1.06193, 'Ti' : 0.997057, 'Zr' : 1.58731, 'Al' : 0, 'V' : 0.905523, 'Si' : 0, 'Sc' : 1.11908, 'Sb' : 0.844488, 'Ta' : 1.55029, 'Mg' : 0, 'O' : 0, 'Cs' : 0, 'Rb' : 0, 'K' : 0, 'Na' : 0, 'Li' : 0, 'Y' : 1.77384 }

orb_rad_rf = {'Ba' : 0, 'Ca' : 0, 'Sr' : 0, 'Pb' : 0.346519 , 'Ti' : 0, 'Zr' : 0, 'Al' : 0, 'V' : 0, 'Si' : 0, 'Sc' : 0, 'Sb' : 0, 'Ta' : 0.437438, 'Mg' : 0, 'O' : 0, 'Cs' : 0, 'Rb' : 0, 'K' : 0, 'Na' : 0, 'Li' : 0, 'Y' : 0}

atomic_radii = {'Ba' : Ba.atomic_radius * 0.01, 'Sr' : Sr.atomic_radius * 0.01, 'Ca' : Ca.atomic_radius * 0.01, 'Pb' : Pb.atomic_radius * 0.01, 'Ti' : Ti.atomic_radius * 0.01 , 'Al' : Al.atomic_radius * 0.01, 'Zr' : Zr.atomic_radius * 0.01, 'V' : V.atomic_radius * 0.01, 'Hf' : Hf.atomic_radius * 0.01, 'Nb' : Nb.atomic_radius * 0.01, 'Si' : Si.atomic_radius * 0.01, 'Sc' : Sc.atomic_radius * 0.01, 'Sb' : Sb.atomic_radius * 0.01, 'Ta' : Ta.atomic_radius * 0.01, 'Mg' : Mg.atomic_radius * 0.01, 'O' : O.atomic_radius * 0.01, 'Cs' : Cs.atomic_radius * 0.01, 'Rb' : Rb.atomic_radius * 0.01, 'K' : K.atomic_radius * 0.01, 'Na' : Na.atomic_radius * 0.01, 'Li' : Li.atomic_radius * 0.01, 'Y' : Y.atomic_radius * 0.01}

hoe = {'Ba' : -0.078699, 'Ca' : -0.141411, 'Sr' : -0.131793, 'Pb' : -0.41831 , 'Ti' :-0.17001 , 'Zr' : -0.150673, 'Al' : -0.102545, 'V' : -0.204634, 'Si' : -0.153293, 'Sc' : -0.13108, 'Sb' : -0.185623, 'Ta' : -0.182464, 'Mg' : -0.175427, 'O' : -0.338381, 'Cs' : -0.078699, 'Rb' : -0.085375, 'K' : -0.088815, 'Na' : -0.103415, 'Li' : -0.10554, 'Y' : -0.108691}

lue = {'Ba' : -0.078699, 'Ca' : -0.141411, 'Sr' : -0.131793, 'Pb' : -0.41831 , 'Ti' :-0.17001 , 'Zr' : -0.150673, 'Al' : -0.102545, 'V' : -0.204634, 'Si' : -0.153293, 'Sc' : -0.13108, 'Sb' : -0.185623, 'Ta' : -0.182464, 'Mg' : -0.175427, 'O' : -0.338381, 'Cs' : -0.078699, 'Rb' : -0.085375, 'K' : -0.088815, 'Na' : -0.103415, 'Li' : -0.10554, 'Y' : -0.108691}

#distance between the subs
D12 = 4.035
D13 = 4.035
D14 = 5.706
D15 = 4.035
D16 = 5.706
D17 = 5.706
D18 = 6.988
D23 = 5.706
D24 = 4.035
D25 = 5.706
D26 = 4.035
D27 = 6.988
D28 = 5.706 
D34 = 4.035
D35 = 5.706
D36 = 6.988
D37 = 4.035
D38 = 5.706
D45 = 6.988
D46 = 5.706
D47 = 5.706
D48 = 4.035
D56 = 4.035
D57 = 4.035
D58 = 5.706
D67 = 5.706
D68 = 4.035
D78 = 4.035
# Out:
#      Unnamed: 0         formula site1 site2 site3 site4 site5 site6 site7  \
# 0             0  Ba2Ca3Y3Al8O24    Ca    Ca     Y    Ca     Y     Y    Ba
# 1             1  Ba2Ca3Y3Al8O24    Ca    Ca    Ca     Y     Y     Y    Ba
# 2             2  Ba2Ca3Y3Al8O24    Ca     Y    Ca    Ca     Y     Y    Ba
# 3             3  Ba2Ca3Y3Al8O24     Y    Ca    Ca    Ca     Y     Y    Ba
# 4             4  Ba2Ca3Y3Al8O24    Ca    Ca     Y     Y    Ca     Y    Ba
# ..          ...             ...   ...   ...   ...   ...   ...   ...   ...
# 814         814    Sr4Ca4Ti8O24    Sr    Sr    Sr    Ca    Ca    Ca    Ca
# 815         815    Sr4Ca4Ti8O24    Sr    Sr    Sr    Ca    Ca    Ca    Sr
# 816         816    Sr4Ca4Ti8O24    Sr    Sr    Sr    Ca    Ca    Sr    Ca
# 817         817    Sr4Ca4Ti8O24    Sr    Sr    Sr    Ca    Sr    Ca    Ca
# 818         818    Sr4Ca4Ti8O24    Sr    Sr    Sr    Sr    Ca    Ca    Ca
#
#     site8   bandgap
# 0      Ba  1.462422
# 1      Ba  1.462142
# ...

# %%
#mapping
#elenegativity

compositions_Ti_family['elenega1'] = compositions_Ti_family['site1'].map(elenega)
compositions_Ti_family['elenega2'] = compositions_Ti_family['site2'].map(elenega)
compositions_Ti_family['elenega3'] = compositions_Ti_family['site3'].map(elenega)
compositions_Ti_family['elenega4'] = compositions_Ti_family['site4'].map(elenega)
compositions_Ti_family['elenega5'] = compositions_Ti_family['site5'].map(elenega)
compositions_Ti_family['elenega6'] = compositions_Ti_family['site6'].map(elenega)
compositions_Ti_family['elenega7'] = compositions_Ti_family['site7'].map(elenega)
compositions_Ti_family['elenega8'] = compositions_Ti_family['site8'].map(elenega)

#eleaffinity

compositions_Ti_family['eleaff1'] = compositions_Ti_family['site1'].map(eleaff)
compositions_Ti_family['eleaff2'] = compositions_Ti_family['site2'].map(eleaff)
compositions_Ti_family['eleaff3'] = compositions_Ti_family['site3'].map(eleaff)
compositions_Ti_family['eleaff4'] = compositions_Ti_family['site4'].map(eleaff)
compositions_Ti_family['eleaff5'] = compositions_Ti_family['site5'].map(eleaff)
compositions_Ti_family['eleaff6'] = compositions_Ti_family['site6'].map(eleaff)
compositions_Ti_family['eleaff7'] = compositions_Ti_family['site7'].map(eleaff)
compositions_Ti_family['eleaff8'] = compositions_Ti_family['site8'].map(eleaff)

#ionz1

compositions_Ti_family['ionz1_1'] = compositions_Ti_family['site1'].map(ioniz1)
compositions_Ti_family['ionz1_2'] = compositions_Ti_family['site2'].map(ioniz1)
compositions_Ti_family['ionz1_3'] = compositions_Ti_family['site3'].map(ioniz1)
compositions_Ti_family['ionz1_4'] = compositions_Ti_family['site4'].map(ioniz1)
compositions_Ti_family['ionz1_5'] = compositions_Ti_family['site5'].map(ioniz1)
compositions_Ti_family['ionz1_6'] = compositions_Ti_family['site6'].map(ioniz1)
compositions_Ti_family['ionz1_7'] = compositions_Ti_family['site7'].map(ioniz1)
compositions_Ti_family['ionz1_8'] = compositions_Ti_family['site8'].map(ioniz1)

#ionz2

compositions_Ti_family['ionz2_1'] = compositions_Ti_family['site1'].map(ioniz2)
compositions_Ti_family['ionz2_2'] = compositions_Ti_family['site2'].map(ioniz2)
compositions_Ti_family['ionz2_3'] = compositions_Ti_family['site3'].map(ioniz2)
compositions_Ti_family['ionz2_4'] = compositions_Ti_family['site4'].map(ioniz2)
compositions_Ti_family['ionz2_5'] = compositions_Ti_family['site5'].map(ioniz2)
compositions_Ti_family['ionz2_6'] = compositions_Ti_family['site6'].map(ioniz2)
compositions_Ti_family['ionz2_7'] = compositions_Ti_family['site7'].map(ioniz2)
compositions_Ti_family['ionz2_8'] = compositions_Ti_family['site8'].map(ioniz2)

#ionz3

compositions_Ti_family['ionz3_1'] = compositions_Ti_family['site1'].map(ioniz3)
compositions_Ti_family['ionz3_2'] = compositions_Ti_family['site2'].map(ioniz3)
compositions_Ti_family['ionz3_3'] = compositions_Ti_family['site3'].map(ioniz3)
compositions_Ti_family['ionz3_4'] = compositions_Ti_family['site4'].map(ioniz3)
compositions_Ti_family['ionz3_5'] = compositions_Ti_family['site5'].map(ioniz3)
compositions_Ti_family['ionz3_6'] = compositions_Ti_family['site6'].map(ioniz3)
compositions_Ti_family['ionz3_7'] = compositions_Ti_family['site7'].map(ioniz3)
compositions_Ti_family['ionz3_8'] = compositions_Ti_family['site8'].map(ioniz3)

#ionz4

compositions_Ti_family['ionz4_1'] = compositions_Ti_family['site1'].map(ioniz4)
compositions_Ti_family['ionz4_2'] = compositions_Ti_family['site2'].map(ioniz4)
compositions_Ti_family['ionz4_3'] = compositions_Ti_family['site3'].map(ioniz4)
compositions_Ti_family['ionz4_4'] = compositions_Ti_family['site4'].map(ioniz4)
compositions_Ti_family['ionz4_5'] = compositions_Ti_family['site5'].map(ioniz4)
compositions_Ti_family['ionz4_6'] = compositions_Ti_family['site6'].map(ioniz4)
compositions_Ti_family['ionz4_7'] = compositions_Ti_family['site7'].map(ioniz4)
compositions_Ti_family['ionz4_8'] = compositions_Ti_family['site8'].map(ioniz4)

#ionz5

compositions_Ti_family['ionz5_1'] = compositions_Ti_family['site1'].map(ioniz5)
compositions_Ti_family['ionz5_2'] = compositions_Ti_family['site2'].map(ioniz5)
compositions_Ti_family['ionz5_3'] = compositions_Ti_family['site3'].map(ioniz5)
compositions_Ti_family['ionz5_4'] = compositions_Ti_family['site4'].map(ioniz5)
compositions_Ti_family['ionz5_5'] = compositions_Ti_family['site5'].map(ioniz5)
compositions_Ti_family['ionz5_6'] = compositions_Ti_family['site6'].map(ioniz5)
compositions_Ti_family['ionz5_7'] = compositions_Ti_family['site7'].map(ioniz5)
compositions_Ti_family['ionz5_8'] = compositions_Ti_family['site8'].map(ioniz5)

#ionz6

compositions_Ti_family['ionz6_1'] = compositions_Ti_family['site1'].map(ioniz6)
compositions_Ti_family['ionz6_2'] = compositions_Ti_family['site2'].map(ioniz6)
compositions_Ti_family['ionz6_3'] = compositions_Ti_family['site3'].map(ioniz6)
compositions_Ti_family['ionz6_4'] = compositions_Ti_family['site4'].map(ioniz6)
compositions_Ti_family['ionz6_5'] = compositions_Ti_family['site5'].map(ioniz6)
compositions_Ti_family['ionz6_6'] = compositions_Ti_family['site6'].map(ioniz6)
compositions_Ti_family['ionz6_7'] = compositions_Ti_family['site7'].map(ioniz6)
compositions_Ti_family['ionz6_8'] = compositions_Ti_family['site8'].map(ioniz6)

#orb_radius_s

compositions_Ti_family['orb_rad_rs_1'] = compositions_Ti_family['site1'].map(orb_rad_rs)
compositions_Ti_family['orb_rad_rs_2'] = compositions_Ti_family['site2'].map(orb_rad_rs)
compositions_Ti_family['orb_rad_rs_3'] = compositions_Ti_family['site3'].map(orb_rad_rs)
compositions_Ti_family['orb_rad_rs_4'] = compositions_Ti_family['site4'].map(orb_rad_rs)
compositions_Ti_family['orb_rad_rs_5'] = compositions_Ti_family['site5'].map(orb_rad_rs)
compositions_Ti_family['orb_rad_rs_6'] = compositions_Ti_family['site6'].map(orb_rad_rs)
compositions_Ti_family['orb_rad_rs_7'] = compositions_Ti_family['site7'].map(orb_rad_rs)
compositions_Ti_family['orb_rad_rs_8'] = compositions_Ti_family['site8'].map(orb_rad_rs)

#orb_radius_p

compositions_Ti_family['orb_rad_rp_1'] = compositions_Ti_family['site1'].map(orb_rad_rp)
compositions_Ti_family['orb_rad_rp_2'] = compositions_Ti_family['site2'].map(orb_rad_rp)
compositions_Ti_family['orb_rad_rp_3'] = compositions_Ti_family['site3'].map(orb_rad_rp)
compositions_Ti_family['orb_rad_rp_4'] = compositions_Ti_family['site4'].map(orb_rad_rp)
compositions_Ti_family['orb_rad_rp_5'] = compositions_Ti_family['site5'].map(orb_rad_rp)
compositions_Ti_family['orb_rad_rp_6'] = compositions_Ti_family['site6'].map(orb_rad_rp)
compositions_Ti_family['orb_rad_rp_7'] = compositions_Ti_family['site7'].map(orb_rad_rp)
compositions_Ti_family['orb_rad_rp_8'] = compositions_Ti_family['site8'].map(orb_rad_rp)

#orb_radius_d

compositions_Ti_family['orb_rad_rd_1'] = compositions_Ti_family['site1'].map(orb_rad_rd)
compositions_Ti_family['orb_rad_rd_2'] = compositions_Ti_family['site2'].map(orb_rad_rd)
compositions_Ti_family['orb_rad_rd_3'] = compositions_Ti_family['site3'].map(orb_rad_rd)
compositions_Ti_family['orb_rad_rd_4'] = compositions_Ti_family['site4'].map(orb_rad_rd)
compositions_Ti_family['orb_rad_rd_5'] = compositions_Ti_family['site5'].map(orb_rad_rd)
compositions_Ti_family['orb_rad_rd_6'] = compositions_Ti_family['site6'].map(orb_rad_rd)
compositions_Ti_family['orb_rad_rd_7'] = compositions_Ti_family['site7'].map(orb_rad_rd)
compositions_Ti_family['orb_rad_rd_8'] = compositions_Ti_family['site8'].map(orb_rad_rd)

#orb_radius_f

compositions_Ti_family['orb_rad_rf_1'] = compositions_Ti_family['site1'].map(orb_rad_rf)
compositions_Ti_family['orb_rad_rf_2'] = compositions_Ti_family['site2'].map(orb_rad_rf)
compositions_Ti_family['orb_rad_rf_3'] = compositions_Ti_family['site3'].map(orb_rad_rf)
compositions_Ti_family['orb_rad_rf_4'] = compositions_Ti_family['site4'].map(orb_rad_rf)
compositions_Ti_family['orb_rad_rf_5'] = compositions_Ti_family['site5'].map(orb_rad_rf)
compositions_Ti_family['orb_rad_rf_6'] = compositions_Ti_family['site6'].map(orb_rad_rf)
compositions_Ti_family['orb_rad_rf_7'] = compositions_Ti_family['site7'].map(orb_rad_rf)
compositions_Ti_family['orb_rad_rf_8'] = compositions_Ti_family['site8'].map(orb_rad_rf)

#atomic_radii

compositions_Ti_family['atomic_radii_1'] = compositions_Ti_family['site1'].map(atomic_radii)
compositions_Ti_family['atomic_radii_2'] = compositions_Ti_family['site2'].map(atomic_radii)
compositions_Ti_family['atomic_radii_3'] = compositions_Ti_family['site3'].map(atomic_radii)
compositions_Ti_family['atomic_radii_4'] = compositions_Ti_family['site4'].map(atomic_radii)
compositions_Ti_family['atomic_radii_5'] = compositions_Ti_family['site5'].map(atomic_radii)
compositions_Ti_family['atomic_radii_6'] = compositions_Ti_family['site6'].map(atomic_radii)
compositions_Ti_family['atomic_radii_7'] = compositions_Ti_family['site7'].map(atomic_radii)
compositions_Ti_family['atomic_radii_8'] = compositions_Ti_family['site8'].map(atomic_radii)

#homo

compositions_Ti_family['hoe_1'] = compositions_Ti_family['site1'].map(hoe)
compositions_Ti_family['hoe_2'] = compositions_Ti_family['site2'].map(hoe)
compositions_Ti_family['hoe_3'] = compositions_Ti_family['site3'].map(hoe)
compositions_Ti_family['hoe_4'] = compositions_Ti_family['site4'].map(hoe)
compositions_Ti_family['hoe_5'] = compositions_Ti_family['site5'].map(hoe)
compositions_Ti_family['hoe_6'] = compositions_Ti_family['site6'].map(hoe)
compositions_Ti_family['hoe_7'] = compositions_Ti_family['site7'].map(hoe)
compositions_Ti_family['hoe_8'] = compositions_Ti_family['site8'].map(hoe)

#lumo

compositions_Ti_family['lue_1'] = compositions_Ti_family['site1'].map(lue)
compositions_Ti_family['lue_2'] = compositions_Ti_family['site2'].map(lue)
compositions_Ti_family['lue_3'] = compositions_Ti_family['site3'].map(lue)
compositions_Ti_family['lue_4'] = compositions_Ti_family['site4'].map(lue)
compositions_Ti_family['lue_5'] = compositions_Ti_family['site5'].map(lue)
compositions_Ti_family['lue_6'] = compositions_Ti_family['site6'].map(lue)
compositions_Ti_family['lue_7'] = compositions_Ti_family['site7'].map(lue)
compositions_Ti_family['lue_8'] = compositions_Ti_family['site8'].map(lue)

# %%
#AC1

compositions_Ti_family['elenega_ac'] =  (compositions_Ti_family['elenega1'].astype('float64') * compositions_Ti_family['elenega2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['elenega1'].astype('float64') * compositions_Ti_family['elenega3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['elenega1'].astype('float64') * compositions_Ti_family['elenega4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['elenega1'].astype('float64') * compositions_Ti_family['elenega5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['elenega1'].astype('float64') * compositions_Ti_family['elenega6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['elenega1'].astype('float64') * compositions_Ti_family['elenega7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['elenega1'].astype('float64') * compositions_Ti_family['elenega8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['elenega2'].astype('float64') * compositions_Ti_family['elenega3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['elenega2'].astype('float64') * compositions_Ti_family['elenega4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['elenega2'].astype('float64') * compositions_Ti_family['elenega5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['elenega2'].astype('float64') * compositions_Ti_family['elenega6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['elenega2'].astype('float64') * compositions_Ti_family['elenega7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['elenega2'].astype('float64') * compositions_Ti_family['elenega8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['elenega3'].astype('float64') * compositions_Ti_family['elenega4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['elenega3'].astype('float64') * compositions_Ti_family['elenega5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['elenega3'].astype('float64') * compositions_Ti_family['elenega6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['elenega3'].astype('float64') * compositions_Ti_family['elenega7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['elenega3'].astype('float64') * compositions_Ti_family['elenega8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['elenega4'].astype('float64') * compositions_Ti_family['elenega5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['elenega4'].astype('float64') * compositions_Ti_family['elenega6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['elenega4'].astype('float64') * compositions_Ti_family['elenega7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['elenega4'].astype('float64') * compositions_Ti_family['elenega8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['elenega5'].astype('float64') * compositions_Ti_family['elenega6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['elenega5'].astype('float64') * compositions_Ti_family['elenega7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['elenega5'].astype('float64') * compositions_Ti_family['elenega8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['elenega6'].astype('float64') * compositions_Ti_family['elenega7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['elenega6'].astype('float64') * compositions_Ti_family['elenega8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['elenega7'].astype('float64') * compositions_Ti_family['elenega8'].astype('float64'))/D78
                                      

compositions_Ti_family['eleaff_ac'] =   (compositions_Ti_family['eleaff1'].astype('float64') * compositions_Ti_family['eleaff2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['eleaff1'].astype('float64') * compositions_Ti_family['eleaff3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['eleaff1'].astype('float64') * compositions_Ti_family['eleaff4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['eleaff1'].astype('float64') * compositions_Ti_family['eleaff5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['eleaff1'].astype('float64') * compositions_Ti_family['eleaff6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['eleaff1'].astype('float64') * compositions_Ti_family['eleaff7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['eleaff1'].astype('float64') * compositions_Ti_family['eleaff8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['eleaff2'].astype('float64') * compositions_Ti_family['eleaff3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['eleaff2'].astype('float64') * compositions_Ti_family['eleaff4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['eleaff2'].astype('float64') * compositions_Ti_family['eleaff5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['eleaff2'].astype('float64') * compositions_Ti_family['eleaff6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['eleaff2'].astype('float64') * compositions_Ti_family['eleaff7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['eleaff2'].astype('float64') * compositions_Ti_family['eleaff8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['eleaff3'].astype('float64') * compositions_Ti_family['eleaff4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['eleaff3'].astype('float64') * compositions_Ti_family['eleaff5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['eleaff3'].astype('float64') * compositions_Ti_family['eleaff6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['eleaff3'].astype('float64') * compositions_Ti_family['eleaff7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['eleaff3'].astype('float64') * compositions_Ti_family['eleaff8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['eleaff4'].astype('float64') * compositions_Ti_family['eleaff5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['eleaff4'].astype('float64') * compositions_Ti_family['eleaff6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['eleaff4'].astype('float64') * compositions_Ti_family['eleaff7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['eleaff4'].astype('float64') * compositions_Ti_family['eleaff8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['eleaff5'].astype('float64') * compositions_Ti_family['eleaff6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['eleaff5'].astype('float64') * compositions_Ti_family['eleaff7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['eleaff5'].astype('float64') * compositions_Ti_family['eleaff8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['eleaff6'].astype('float64') * compositions_Ti_family['eleaff7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['eleaff6'].astype('float64') * compositions_Ti_family['eleaff8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['eleaff7'].astype('float64') * compositions_Ti_family['eleaff8'].astype('float64'))/D78
                                      

compositions_Ti_family['ionz1_ac'] =    (compositions_Ti_family['ionz1_1'].astype('float64') * compositions_Ti_family['ionz1_2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['ionz1_1'].astype('float64') * compositions_Ti_family['ionz1_3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['ionz1_1'].astype('float64') * compositions_Ti_family['ionz1_4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['ionz1_1'].astype('float64') * compositions_Ti_family['ionz1_5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['ionz1_1'].astype('float64') * compositions_Ti_family['ionz1_6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['ionz1_1'].astype('float64') * compositions_Ti_family['ionz1_7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['ionz1_1'].astype('float64') * compositions_Ti_family['ionz1_8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['ionz1_2'].astype('float64') * compositions_Ti_family['ionz1_3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['ionz1_2'].astype('float64') * compositions_Ti_family['ionz1_4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['ionz1_2'].astype('float64') * compositions_Ti_family['ionz1_5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['ionz1_2'].astype('float64') * compositions_Ti_family['ionz1_6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['ionz1_2'].astype('float64') * compositions_Ti_family['ionz1_7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['ionz1_2'].astype('float64') * compositions_Ti_family['ionz1_8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['ionz1_3'].astype('float64') * compositions_Ti_family['ionz1_4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['ionz1_3'].astype('float64') * compositions_Ti_family['ionz1_5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['ionz1_3'].astype('float64') * compositions_Ti_family['ionz1_6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['ionz1_3'].astype('float64') * compositions_Ti_family['ionz1_7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['ionz1_3'].astype('float64') * compositions_Ti_family['ionz1_8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['ionz1_4'].astype('float64') * compositions_Ti_family['ionz1_5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['ionz1_4'].astype('float64') * compositions_Ti_family['ionz1_6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['ionz1_4'].astype('float64') * compositions_Ti_family['ionz1_7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['ionz1_4'].astype('float64') * compositions_Ti_family['ionz1_8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['ionz1_5'].astype('float64') * compositions_Ti_family['ionz1_6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['ionz1_5'].astype('float64') * compositions_Ti_family['ionz1_7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['ionz1_5'].astype('float64') * compositions_Ti_family['ionz1_8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['ionz1_6'].astype('float64') * compositions_Ti_family['ionz1_7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['ionz1_6'].astype('float64') * compositions_Ti_family['ionz1_8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['ionz1_7'].astype('float64') * compositions_Ti_family['ionz1_8'].astype('float64'))/D78


compositions_Ti_family['ionz2_ac'] =    (compositions_Ti_family['ionz2_1'].astype('float64') * compositions_Ti_family['ionz2_2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['ionz2_1'].astype('float64') * compositions_Ti_family['ionz2_3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['ionz2_1'].astype('float64') * compositions_Ti_family['ionz2_4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['ionz2_1'].astype('float64') * compositions_Ti_family['ionz2_5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['ionz2_1'].astype('float64') * compositions_Ti_family['ionz2_6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['ionz2_1'].astype('float64') * compositions_Ti_family['ionz2_7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['ionz2_1'].astype('float64') * compositions_Ti_family['ionz2_8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['ionz2_2'].astype('float64') * compositions_Ti_family['ionz2_3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['ionz2_2'].astype('float64') * compositions_Ti_family['ionz2_4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['ionz2_2'].astype('float64') * compositions_Ti_family['ionz2_5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['ionz2_2'].astype('float64') * compositions_Ti_family['ionz2_6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['ionz2_2'].astype('float64') * compositions_Ti_family['ionz2_7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['ionz2_2'].astype('float64') * compositions_Ti_family['ionz2_8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['ionz2_3'].astype('float64') * compositions_Ti_family['ionz2_4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['ionz2_3'].astype('float64') * compositions_Ti_family['ionz2_5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['ionz2_3'].astype('float64') * compositions_Ti_family['ionz2_6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['ionz2_3'].astype('float64') * compositions_Ti_family['ionz2_7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['ionz2_3'].astype('float64') * compositions_Ti_family['ionz2_8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['ionz2_4'].astype('float64') * compositions_Ti_family['ionz2_5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['ionz2_4'].astype('float64') * compositions_Ti_family['ionz2_6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['ionz2_4'].astype('float64') * compositions_Ti_family['ionz2_7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['ionz2_4'].astype('float64') * compositions_Ti_family['ionz2_8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['ionz2_5'].astype('float64') * compositions_Ti_family['ionz2_6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['ionz2_5'].astype('float64') * compositions_Ti_family['ionz2_7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['ionz2_5'].astype('float64') * compositions_Ti_family['ionz2_8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['ionz2_6'].astype('float64') * compositions_Ti_family['ionz2_7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['ionz2_6'].astype('float64') * compositions_Ti_family['ionz2_8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['ionz2_7'].astype('float64') * compositions_Ti_family['ionz2_8'].astype('float64'))/D78

compositions_Ti_family['ionz3_ac'] =    (compositions_Ti_family['ionz3_1'].astype('float64') * compositions_Ti_family['ionz3_2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['ionz3_1'].astype('float64') * compositions_Ti_family['ionz3_3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['ionz3_1'].astype('float64') * compositions_Ti_family['ionz3_4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['ionz3_1'].astype('float64') * compositions_Ti_family['ionz3_5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['ionz3_1'].astype('float64') * compositions_Ti_family['ionz3_6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['ionz3_1'].astype('float64') * compositions_Ti_family['ionz3_7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['ionz3_1'].astype('float64') * compositions_Ti_family['ionz3_8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['ionz3_2'].astype('float64') * compositions_Ti_family['ionz3_3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['ionz3_2'].astype('float64') * compositions_Ti_family['ionz3_4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['ionz3_2'].astype('float64') * compositions_Ti_family['ionz3_5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['ionz3_2'].astype('float64') * compositions_Ti_family['ionz3_6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['ionz3_2'].astype('float64') * compositions_Ti_family['ionz3_7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['ionz3_2'].astype('float64') * compositions_Ti_family['ionz3_8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['ionz3_3'].astype('float64') * compositions_Ti_family['ionz3_4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['ionz3_3'].astype('float64') * compositions_Ti_family['ionz3_5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['ionz3_3'].astype('float64') * compositions_Ti_family['ionz3_6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['ionz3_3'].astype('float64') * compositions_Ti_family['ionz3_7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['ionz3_3'].astype('float64') * compositions_Ti_family['ionz3_8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['ionz3_4'].astype('float64') * compositions_Ti_family['ionz3_5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['ionz3_4'].astype('float64') * compositions_Ti_family['ionz3_6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['ionz3_4'].astype('float64') * compositions_Ti_family['ionz3_7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['ionz3_4'].astype('float64') * compositions_Ti_family['ionz3_8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['ionz3_5'].astype('float64') * compositions_Ti_family['ionz3_6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['ionz3_5'].astype('float64') * compositions_Ti_family['ionz3_7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['ionz3_5'].astype('float64') * compositions_Ti_family['ionz3_8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['ionz3_6'].astype('float64') * compositions_Ti_family['ionz3_7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['ionz3_6'].astype('float64') * compositions_Ti_family['ionz3_8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['ionz3_7'].astype('float64') * compositions_Ti_family['ionz3_8'].astype('float64'))/D78

compositions_Ti_family['ionz4_ac'] =    (compositions_Ti_family['ionz4_1'].astype('float64') * compositions_Ti_family['ionz4_2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['ionz4_1'].astype('float64') * compositions_Ti_family['ionz4_3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['ionz4_1'].astype('float64') * compositions_Ti_family['ionz4_4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['ionz4_1'].astype('float64') * compositions_Ti_family['ionz4_5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['ionz4_1'].astype('float64') * compositions_Ti_family['ionz4_6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['ionz4_1'].astype('float64') * compositions_Ti_family['ionz4_7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['ionz4_1'].astype('float64') * compositions_Ti_family['ionz4_8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['ionz4_2'].astype('float64') * compositions_Ti_family['ionz4_3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['ionz4_2'].astype('float64') * compositions_Ti_family['ionz4_4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['ionz4_2'].astype('float64') * compositions_Ti_family['ionz4_5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['ionz4_2'].astype('float64') * compositions_Ti_family['ionz4_6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['ionz4_2'].astype('float64') * compositions_Ti_family['ionz4_7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['ionz4_2'].astype('float64') * compositions_Ti_family['ionz4_8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['ionz4_3'].astype('float64') * compositions_Ti_family['ionz4_4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['ionz4_3'].astype('float64') * compositions_Ti_family['ionz4_5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['ionz4_3'].astype('float64') * compositions_Ti_family['ionz4_6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['ionz4_3'].astype('float64') * compositions_Ti_family['ionz4_7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['ionz4_3'].astype('float64') * compositions_Ti_family['ionz4_8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['ionz4_4'].astype('float64') * compositions_Ti_family['ionz4_5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['ionz4_4'].astype('float64') * compositions_Ti_family['ionz4_6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['ionz4_4'].astype('float64') * compositions_Ti_family['ionz4_7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['ionz4_4'].astype('float64') * compositions_Ti_family['ionz4_8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['ionz4_5'].astype('float64') * compositions_Ti_family['ionz4_6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['ionz4_5'].astype('float64') * compositions_Ti_family['ionz4_7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['ionz4_5'].astype('float64') * compositions_Ti_family['ionz4_8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['ionz4_6'].astype('float64') * compositions_Ti_family['ionz4_7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['ionz4_6'].astype('float64') * compositions_Ti_family['ionz4_8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['ionz4_7'].astype('float64') * compositions_Ti_family['ionz4_8'].astype('float64'))/D78


compositions_Ti_family['ionz5_ac'] =    (compositions_Ti_family['ionz5_1'].astype('float64') * compositions_Ti_family['ionz5_2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['ionz5_1'].astype('float64') * compositions_Ti_family['ionz5_3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['ionz5_1'].astype('float64') * compositions_Ti_family['ionz5_4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['ionz5_1'].astype('float64') * compositions_Ti_family['ionz5_5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['ionz5_1'].astype('float64') * compositions_Ti_family['ionz5_6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['ionz5_1'].astype('float64') * compositions_Ti_family['ionz5_7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['ionz5_1'].astype('float64') * compositions_Ti_family['ionz5_8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['ionz5_2'].astype('float64') * compositions_Ti_family['ionz5_3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['ionz5_2'].astype('float64') * compositions_Ti_family['ionz5_4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['ionz5_2'].astype('float64') * compositions_Ti_family['ionz5_5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['ionz5_2'].astype('float64') * compositions_Ti_family['ionz5_6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['ionz5_2'].astype('float64') * compositions_Ti_family['ionz5_7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['ionz5_2'].astype('float64') * compositions_Ti_family['ionz5_8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['ionz5_3'].astype('float64') * compositions_Ti_family['ionz5_4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['ionz5_3'].astype('float64') * compositions_Ti_family['ionz5_5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['ionz5_3'].astype('float64') * compositions_Ti_family['ionz5_6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['ionz5_3'].astype('float64') * compositions_Ti_family['ionz5_7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['ionz5_3'].astype('float64') * compositions_Ti_family['ionz5_8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['ionz5_4'].astype('float64') * compositions_Ti_family['ionz5_5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['ionz5_4'].astype('float64') * compositions_Ti_family['ionz5_6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['ionz5_4'].astype('float64') * compositions_Ti_family['ionz5_7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['ionz5_4'].astype('float64') * compositions_Ti_family['ionz5_8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['ionz5_5'].astype('float64') * compositions_Ti_family['ionz5_6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['ionz5_5'].astype('float64') * compositions_Ti_family['ionz5_7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['ionz5_5'].astype('float64') * compositions_Ti_family['ionz5_8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['ionz5_6'].astype('float64') * compositions_Ti_family['ionz5_7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['ionz5_6'].astype('float64') * compositions_Ti_family['ionz5_8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['ionz5_7'].astype('float64') * compositions_Ti_family['ionz5_8'].astype('float64'))/D78

compositions_Ti_family['ionz6_ac'] =    (compositions_Ti_family['ionz6_1'].astype('float64') * compositions_Ti_family['ionz6_2'].astype('float64'))/D12\
                                      + (compositions_Ti_family['ionz6_1'].astype('float64') * compositions_Ti_family['ionz6_3'].astype('float64'))/D13\
                                      + (compositions_Ti_family['ionz6_1'].astype('float64') * compositions_Ti_family['ionz6_4'].astype('float64'))/D14\
                                      + (compositions_Ti_family['ionz6_1'].astype('float64') * compositions_Ti_family['ionz6_5'].astype('float64'))/D15\
                                      + (compositions_Ti_family['ionz6_1'].astype('float64') * compositions_Ti_family['ionz6_6'].astype('float64'))/D16\
                                      + (compositions_Ti_family['ionz6_1'].astype('float64') * compositions_Ti_family['ionz6_7'].astype('float64'))/D17\
                                      + (compositions_Ti_family['ionz6_1'].astype('float64') * compositions_Ti_family['ionz6_8'].astype('float64'))/D18\
                                      + (compositions_Ti_family['ionz6_2'].astype('float64') * compositions_Ti_family['ionz6_3'].astype('float64'))/D23\
                                      + (compositions_Ti_family['ionz6_2'].astype('float64') * compositions_Ti_family['ionz6_4'].astype('float64'))/D24\
                                      + (compositions_Ti_family['ionz6_2'].astype('float64') * compositions_Ti_family['ionz6_5'].astype('float64'))/D25\
                                      + (compositions_Ti_family['ionz6_2'].astype('float64') * compositions_Ti_family['ionz6_6'].astype('float64'))/D26\
                                      + (compositions_Ti_family['ionz6_2'].astype('float64') * compositions_Ti_family['ionz6_7'].astype('float64'))/D27\
                                      + (compositions_Ti_family['ionz6_2'].astype('float64') * compositions_Ti_family['ionz6_8'].astype('float64'))/D28\
                                      + (compositions_Ti_family['ionz6_3'].astype('float64') * compositions_Ti_family['ionz6_4'].astype('float64'))/D34\
                                      + (compositions_Ti_family['ionz6_3'].astype('float64') * compositions_Ti_family['ionz6_5'].astype('float64'))/D35\
                                      + (compositions_Ti_family['ionz6_3'].astype('float64') * compositions_Ti_family['ionz6_6'].astype('float64'))/D36\
                                      + (compositions_Ti_family['ionz6_3'].astype('float64') * compositions_Ti_family['ionz6_7'].astype('float64'))/D37\
                                      + (compositions_Ti_family['ionz6_3'].astype('float64') * compositions_Ti_family['ionz6_8'].astype('float64'))/D38\
                                      + (compositions_Ti_family['ionz6_4'].astype('float64') * compositions_Ti_family['ionz6_5'].astype('float64'))/D45\
                                      + (compositions_Ti_family['ionz6_4'].astype('float64') * compositions_Ti_family['ionz6_6'].astype('float64'))/D46\
                                      + (compositions_Ti_family['ionz6_4'].astype('float64') * compositions_Ti_family['ionz6_7'].astype('float64'))/D47\
                                      + (compositions_Ti_family['ionz6_4'].astype('float64') * compositions_Ti_family['ionz6_8'].astype('float64'))/D48\
                                      + (compositions_Ti_family['ionz6_5'].astype('float64') * compositions_Ti_family['ionz6_6'].astype('float64'))/D56\
                                      + (compositions_Ti_family['ionz6_5'].astype('float64') * compositions_Ti_family['ionz6_7'].astype('float64'))/D57\
                                      + (compositions_Ti_family['ionz6_5'].astype('float64') * compositions_Ti_family['ionz6_8'].astype('float64'))/D58\
                                      + (compositions_Ti_family['ionz6_6'].astype('float64') * compositions_Ti_family['ionz6_7'].astype('float64'))/D67\
                                      + (compositions_Ti_family['ionz6_6'].astype('float64') * compositions_Ti_family['ionz6_8'].astype('float64'))/D68\
                                      + (compositions_Ti_family['ionz6_7'].astype('float64') * compositions_Ti_family['ionz6_8'].astype('float64'))/D78


compositions_Ti_family['orb_rad_rs_ac'] =    (compositions_Ti_family['orb_rad_rs_1'].astype('float64') * compositions_Ti_family['orb_rad_rs_2'].astype('float64'))/D12\
                                           + (compositions_Ti_family['orb_rad_rs_1'].astype('float64') * compositions_Ti_family['orb_rad_rs_3'].astype('float64'))/D13\
                                           + (compositions_Ti_family['orb_rad_rs_1'].astype('float64') * compositions_Ti_family['orb_rad_rs_4'].astype('float64'))/D14\
                                           + (compositions_Ti_family['orb_rad_rs_1'].astype('float64') * compositions_Ti_family['orb_rad_rs_5'].astype('float64'))/D15\
                                           + (compositions_Ti_family['orb_rad_rs_1'].astype('float64') * compositions_Ti_family['orb_rad_rs_6'].astype('float64'))/D16\
                                           + (compositions_Ti_family['orb_rad_rs_1'].astype('float64') * compositions_Ti_family['orb_rad_rs_7'].astype('float64'))/D17\
                                           + (compositions_Ti_family['orb_rad_rs_1'].astype('float64') * compositions_Ti_family['orb_rad_rs_8'].astype('float64'))/D18\
                                           + (compositions_Ti_family['orb_rad_rs_2'].astype('float64') * compositions_Ti_family['orb_rad_rs_3'].astype('float64'))/D23\
                                           + (compositions_Ti_family['orb_rad_rs_2'].astype('float64') * compositions_Ti_family['orb_rad_rs_4'].astype('float64'))/D24\
                                           + (compositions_Ti_family['orb_rad_rs_2'].astype('float64') * compositions_Ti_family['orb_rad_rs_5'].astype('float64'))/D25\
                                           + (compositions_Ti_family['orb_rad_rs_2'].astype('float64') * compositions_Ti_family['orb_rad_rs_6'].astype('float64'))/D26\
                                           + (compositions_Ti_family['orb_rad_rs_2'].astype('float64') * compositions_Ti_family['orb_rad_rs_7'].astype('float64'))/D27\
                                           + (compositions_Ti_family['orb_rad_rs_2'].astype('float64') * compositions_Ti_family['orb_rad_rs_8'].astype('float64'))/D28\
                                           + (compositions_Ti_family['orb_rad_rs_3'].astype('float64') * compositions_Ti_family['orb_rad_rs_4'].astype('float64'))/D34\
                                           + (compositions_Ti_family['orb_rad_rs_3'].astype('float64') * compositions_Ti_family['orb_rad_rs_5'].astype('float64'))/D35\
                                           + (compositions_Ti_family['orb_rad_rs_3'].astype('float64') * compositions_Ti_family['orb_rad_rs_6'].astype('float64'))/D36\
                                           + (compositions_Ti_family['orb_rad_rs_3'].astype('float64') * compositions_Ti_family['orb_rad_rs_7'].astype('float64'))/D37\
                                           + (compositions_Ti_family['orb_rad_rs_3'].astype('float64') * compositions_Ti_family['orb_rad_rs_8'].astype('float64'))/D38\
                                           + (compositions_Ti_family['orb_rad_rs_4'].astype('float64') * compositions_Ti_family['orb_rad_rs_5'].astype('float64'))/D45\
                                           + (compositions_Ti_family['orb_rad_rs_4'].astype('float64') * compositions_Ti_family['orb_rad_rs_6'].astype('float64'))/D46\
                                           + (compositions_Ti_family['orb_rad_rs_4'].astype('float64') * compositions_Ti_family['orb_rad_rs_7'].astype('float64'))/D47\
                                           + (compositions_Ti_family['orb_rad_rs_4'].astype('float64') * compositions_Ti_family['orb_rad_rs_8'].astype('float64'))/D48\
                                           + (compositions_Ti_family['orb_rad_rs_5'].astype('float64') * compositions_Ti_family['orb_rad_rs_6'].astype('float64'))/D56\
                                           + (compositions_Ti_family['orb_rad_rs_5'].astype('float64') * compositions_Ti_family['orb_rad_rs_7'].astype('float64'))/D57\
                                           + (compositions_Ti_family['orb_rad_rs_5'].astype('float64') * compositions_Ti_family['orb_rad_rs_8'].astype('float64'))/D58\
                                           + (compositions_Ti_family['orb_rad_rs_6'].astype('float64') * compositions_Ti_family['orb_rad_rs_7'].astype('float64'))/D67\
                                           + (compositions_Ti_family['orb_rad_rs_6'].astype('float64') * compositions_Ti_family['orb_rad_rs_8'].astype('float64'))/D68\
                                           + (compositions_Ti_family['orb_rad_rs_7'].astype('float64') * compositions_Ti_family['orb_rad_rs_8'].astype('float64'))/D78



compositions_Ti_family['orb_rad_rp_ac'] =    (compositions_Ti_family['orb_rad_rp_1'].astype('float64') * compositions_Ti_family['orb_rad_rp_2'].astype('float64'))/D12\
                                           + (compositions_Ti_family['orb_rad_rp_1'].astype('float64') * compositions_Ti_family['orb_rad_rp_3'].astype('float64'))/D13\
                                           + (compositions_Ti_family['orb_rad_rp_1'].astype('float64') * compositions_Ti_family['orb_rad_rp_4'].astype('float64'))/D14\
                                           + (compositions_Ti_family['orb_rad_rp_1'].astype('float64') * compositions_Ti_family['orb_rad_rp_5'].astype('float64'))/D15\
                                           + (compositions_Ti_family['orb_rad_rp_1'].astype('float64') * compositions_Ti_family['orb_rad_rp_6'].astype('float64'))/D16\
                                           + (compositions_Ti_family['orb_rad_rp_1'].astype('float64') * compositions_Ti_family['orb_rad_rp_7'].astype('float64'))/D17\
                                           + (compositions_Ti_family['orb_rad_rp_1'].astype('float64') * compositions_Ti_family['orb_rad_rp_8'].astype('float64'))/D18\
                                           + (compositions_Ti_family['orb_rad_rp_2'].astype('float64') * compositions_Ti_family['orb_rad_rp_3'].astype('float64'))/D23\
                                           + (compositions_Ti_family['orb_rad_rp_2'].astype('float64') * compositions_Ti_family['orb_rad_rp_4'].astype('float64'))/D24\
                                           + (compositions_Ti_family['orb_rad_rp_2'].astype('float64') * compositions_Ti_family['orb_rad_rp_5'].astype('float64'))/D25\
                                           + (compositions_Ti_family['orb_rad_rp_2'].astype('float64') * compositions_Ti_family['orb_rad_rp_6'].astype('float64'))/D26\
                                           + (compositions_Ti_family['orb_rad_rp_2'].astype('float64') * compositions_Ti_family['orb_rad_rp_7'].astype('float64'))/D27\
                                           + (compositions_Ti_family['orb_rad_rp_2'].astype('float64') * compositions_Ti_family['orb_rad_rp_8'].astype('float64'))/D28\
                                           + (compositions_Ti_family['orb_rad_rp_3'].astype('float64') * compositions_Ti_family['orb_rad_rp_4'].astype('float64'))/D34\
                                           + (compositions_Ti_family['orb_rad_rp_3'].astype('float64') * compositions_Ti_family['orb_rad_rp_5'].astype('float64'))/D35\
                                           + (compositions_Ti_family['orb_rad_rp_3'].astype('float64') * compositions_Ti_family['orb_rad_rp_6'].astype('float64'))/D36\
                                           + (compositions_Ti_family['orb_rad_rp_3'].astype('float64') * compositions_Ti_family['orb_rad_rp_7'].astype('float64'))/D37\
                                           + (compositions_Ti_family['orb_rad_rp_3'].astype('float64') * compositions_Ti_family['orb_rad_rp_8'].astype('float64'))/D38\
                                           + (compositions_Ti_family['orb_rad_rp_4'].astype('float64') * compositions_Ti_family['orb_rad_rp_5'].astype('float64'))/D45\
                                           + (compositions_Ti_family['orb_rad_rp_4'].astype('float64') * compositions_Ti_family['orb_rad_rp_6'].astype('float64'))/D46\
                                           + (compositions_Ti_family['orb_rad_rp_4'].astype('float64') * compositions_Ti_family['orb_rad_rp_7'].astype('float64'))/D47\
                                           + (compositions_Ti_family['orb_rad_rp_4'].astype('float64') * compositions_Ti_family['orb_rad_rp_8'].astype('float64'))/D48\
                                           + (compositions_Ti_family['orb_rad_rp_5'].astype('float64') * compositions_Ti_family['orb_rad_rp_6'].astype('float64'))/D56\
                                           + (compositions_Ti_family['orb_rad_rp_5'].astype('float64') * compositions_Ti_family['orb_rad_rp_7'].astype('float64'))/D57\
                                           + (compositions_Ti_family['orb_rad_rp_5'].astype('float64') * compositions_Ti_family['orb_rad_rp_8'].astype('float64'))/D58\
                                           + (compositions_Ti_family['orb_rad_rp_6'].astype('float64') * compositions_Ti_family['orb_rad_rp_7'].astype('float64'))/D67\
                                           + (compositions_Ti_family['orb_rad_rp_6'].astype('float64') * compositions_Ti_family['orb_rad_rp_8'].astype('float64'))/D68\
                                           + (compositions_Ti_family['orb_rad_rp_7'].astype('float64') * compositions_Ti_family['orb_rad_rp_8'].astype('float64'))/D78

compositions_Ti_family['orb_rad_rd_ac'] =    (compositions_Ti_family['orb_rad_rd_1'].astype('float64') * compositions_Ti_family['orb_rad_rd_2'].astype('float64'))/D12\
                                           + (compositions_Ti_family['orb_rad_rd_1'].astype('float64') * compositions_Ti_family['orb_rad_rd_3'].astype('float64'))/D13\
                                           + (compositions_Ti_family['orb_rad_rd_1'].astype('float64') * compositions_Ti_family['orb_rad_rd_4'].astype('float64'))/D14\
                                           + (compositions_Ti_family['orb_rad_rd_1'].astype('float64') * compositions_Ti_family['orb_rad_rd_5'].astype('float64'))/D15\
                                           + (compositions_Ti_family['orb_rad_rd_1'].astype('float64') * compositions_Ti_family['orb_rad_rd_6'].astype('float64'))/D16\
                                           + (compositions_Ti_family['orb_rad_rd_1'].astype('float64') * compositions_Ti_family['orb_rad_rd_7'].astype('float64'))/D17\
                                           + (compositions_Ti_family['orb_rad_rd_1'].astype('float64') * compositions_Ti_family['orb_rad_rd_8'].astype('float64'))/D18\
                                           + (compositions_Ti_family['orb_rad_rd_2'].astype('float64') * compositions_Ti_family['orb_rad_rd_3'].astype('float64'))/D23\
                                           + (compositions_Ti_family['orb_rad_rd_2'].astype('float64') * compositions_Ti_family['orb_rad_rd_4'].astype('float64'))/D24\
                                           + (compositions_Ti_family['orb_rad_rd_2'].astype('float64') * compositions_Ti_family['orb_rad_rd_5'].astype('float64'))/D25\
                                           + (compositions_Ti_family['orb_rad_rd_2'].astype('float64') * compositions_Ti_family['orb_rad_rd_6'].astype('float64'))/D26\
                                           + (compositions_Ti_family['orb_rad_rd_2'].astype('float64') * compositions_Ti_family['orb_rad_rd_7'].astype('float64'))/D27\
                                           + (compositions_Ti_family['orb_rad_rd_2'].astype('float64') * compositions_Ti_family['orb_rad_rd_8'].astype('float64'))/D28\
                                           + (compositions_Ti_family['orb_rad_rd_3'].astype('float64') * compositions_Ti_family['orb_rad_rd_4'].astype('float64'))/D34\
                                           + (compositions_Ti_family['orb_rad_rd_3'].astype('float64') * compositions_Ti_family['orb_rad_rd_5'].astype('float64'))/D35\
                                           + (compositions_Ti_family['orb_rad_rd_3'].astype('float64') * compositions_Ti_family['orb_rad_rd_6'].astype('float64'))/D36\
                                           + (compositions_Ti_family['orb_rad_rd_3'].astype('float64') * compositions_Ti_family['orb_rad_rd_7'].astype('float64'))/D37\
                                           + (compositions_Ti_family['orb_rad_rd_3'].astype('float64') * compositions_Ti_family['orb_rad_rd_8'].astype('float64'))/D38\
                                           + (compositions_Ti_family['orb_rad_rd_4'].astype('float64') * compositions_Ti_family['orb_rad_rd_5'].astype('float64'))/D45\
                                           + (compositions_Ti_family['orb_rad_rd_4'].astype('float64') * compositions_Ti_family['orb_rad_rd_6'].astype('float64'))/D46\
                                           + (compositions_Ti_family['orb_rad_rd_4'].astype('float64') * compositions_Ti_family['orb_rad_rd_7'].astype('float64'))/D47\
                                           + (compositions_Ti_family['orb_rad_rd_4'].astype('float64') * compositions_Ti_family['orb_rad_rd_8'].astype('float64'))/D48\
                                           + (compositions_Ti_family['orb_rad_rd_5'].astype('float64') * compositions_Ti_family['orb_rad_rd_6'].astype('float64'))/D56\
                                           + (compositions_Ti_family['orb_rad_rd_5'].astype('float64') * compositions_Ti_family['orb_rad_rd_7'].astype('float64'))/D57\
                                           + (compositions_Ti_family['orb_rad_rd_5'].astype('float64') * compositions_Ti_family['orb_rad_rd_8'].astype('float64'))/D58\
                                           + (compositions_Ti_family['orb_rad_rd_6'].astype('float64') * compositions_Ti_family['orb_rad_rd_7'].astype('float64'))/D67\
                                           + (compositions_Ti_family['orb_rad_rd_6'].astype('float64') * compositions_Ti_family['orb_rad_rd_8'].astype('float64'))/D68\
                                           + (compositions_Ti_family['orb_rad_rd_7'].astype('float64') * compositions_Ti_family['orb_rad_rd_8'].astype('float64'))/D78

compositions_Ti_family['orb_rad_rf_ac'] =    (compositions_Ti_family['orb_rad_rf_1'].astype('float64') * compositions_Ti_family['orb_rad_rf_2'].astype('float64'))/D12\
                                           + (compositions_Ti_family['orb_rad_rf_1'].astype('float64') * compositions_Ti_family['orb_rad_rf_3'].astype('float64'))/D13\
                                           + (compositions_Ti_family['orb_rad_rf_1'].astype('float64') * compositions_Ti_family['orb_rad_rf_4'].astype('float64'))/D14\
                                           + (compositions_Ti_family['orb_rad_rf_1'].astype('float64') * compositions_Ti_family['orb_rad_rf_5'].astype('float64'))/D15\
                                           + (compositions_Ti_family['orb_rad_rf_1'].astype('float64') * compositions_Ti_family['orb_rad_rf_6'].astype('float64'))/D16\
                                           + (compositions_Ti_family['orb_rad_rf_1'].astype('float64') * compositions_Ti_family['orb_rad_rf_7'].astype('float64'))/D17\
                                           + (compositions_Ti_family['orb_rad_rf_1'].astype('float64') * compositions_Ti_family['orb_rad_rf_8'].astype('float64'))/D18\
                                           + (compositions_Ti_family['orb_rad_rf_2'].astype('float64') * compositions_Ti_family['orb_rad_rf_3'].astype('float64'))/D23\
                                           + (compositions_Ti_family['orb_rad_rf_2'].astype('float64') * compositions_Ti_family['orb_rad_rf_4'].astype('float64'))/D24\
                                           + (compositions_Ti_family['orb_rad_rf_2'].astype('float64') * compositions_Ti_family['orb_rad_rf_5'].astype('float64'))/D25\
                                           + (compositions_Ti_family['orb_rad_rf_2'].astype('float64') * compositions_Ti_family['orb_rad_rf_6'].astype('float64'))/D26\
                                           + (compositions_Ti_family['orb_rad_rf_2'].astype('float64') * compositions_Ti_family['orb_rad_rf_7'].astype('float64'))/D27\
                                           + (compositions_Ti_family['orb_rad_rf_2'].astype('float64') * compositions_Ti_family['orb_rad_rf_8'].astype('float64'))/D28\
                                           + (compositions_Ti_family['orb_rad_rf_3'].astype('float64') * compositions_Ti_family['orb_rad_rf_4'].astype('float64'))/D34\
                                           + (compositions_Ti_family['orb_rad_rf_3'].astype('float64') * compositions_Ti_family['orb_rad_rf_5'].astype('float64'))/D35\
                                           + (compositions_Ti_family['orb_rad_rf_3'].astype('float64') * compositions_Ti_family['orb_rad_rf_6'].astype('float64'))/D36\
                                           + (compositions_Ti_family['orb_rad_rf_3'].astype('float64') * compositions_Ti_family['orb_rad_rf_7'].astype('float64'))/D37\
                                           + (compositions_Ti_family['orb_rad_rf_3'].astype('float64') * compositions_Ti_family['orb_rad_rf_8'].astype('float64'))/D38\
                                           + (compositions_Ti_family['orb_rad_rf_4'].astype('float64') * compositions_Ti_family['orb_rad_rf_5'].astype('float64'))/D45\
                                           + (compositions_Ti_family['orb_rad_rf_4'].astype('float64') * compositions_Ti_family['orb_rad_rf_6'].astype('float64'))/D46\
                                           + (compositions_Ti_family['orb_rad_rf_4'].astype('float64') * compositions_Ti_family['orb_rad_rf_7'].astype('float64'))/D47\
                                           + (compositions_Ti_family['orb_rad_rf_4'].astype('float64') * compositions_Ti_family['orb_rad_rf_8'].astype('float64'))/D48\
                                           + (compositions_Ti_family['orb_rad_rf_5'].astype('float64') * compositions_Ti_family['orb_rad_rf_6'].astype('float64'))/D56\
                                           + (compositions_Ti_family['orb_rad_rf_5'].astype('float64') * compositions_Ti_family['orb_rad_rf_7'].astype('float64'))/D57\
                                           + (compositions_Ti_family['orb_rad_rf_5'].astype('float64') * compositions_Ti_family['orb_rad_rf_8'].astype('float64'))/D58\
                                           + (compositions_Ti_family['orb_rad_rf_6'].astype('float64') * compositions_Ti_family['orb_rad_rf_7'].astype('float64'))/D67\
                                           + (compositions_Ti_family['orb_rad_rf_6'].astype('float64') * compositions_Ti_family['orb_rad_rf_8'].astype('float64'))/D68\
                                           + (compositions_Ti_family['orb_rad_rf_7'].astype('float64') * compositions_Ti_family['orb_rad_rf_8'].astype('float64'))/D78


compositions_Ti_family['atomic_radii_ac'] =  (compositions_Ti_family['atomic_radii_1'].astype('float64') * compositions_Ti_family['atomic_radii_2'].astype('float64'))/D12\
                                           + (compositions_Ti_family['atomic_radii_1'].astype('float64') * compositions_Ti_family['atomic_radii_3'].astype('float64'))/D13\
                                           + (compositions_Ti_family['atomic_radii_1'].astype('float64') * compositions_Ti_family['atomic_radii_4'].astype('float64'))/D14\
                                           + (compositions_Ti_family['atomic_radii_1'].astype('float64') * compositions_Ti_family['atomic_radii_5'].astype('float64'))/D15\
                                           + (compositions_Ti_family['atomic_radii_1'].astype('float64') * compositions_Ti_family['atomic_radii_6'].astype('float64'))/D16\
                                           + (compositions_Ti_family['atomic_radii_1'].astype('float64') * compositions_Ti_family['atomic_radii_7'].astype('float64'))/D17\
                                           + (compositions_Ti_family['atomic_radii_1'].astype('float64') * compositions_Ti_family['atomic_radii_8'].astype('float64'))/D18\
                                           + (compositions_Ti_family['atomic_radii_2'].astype('float64') * compositions_Ti_family['atomic_radii_3'].astype('float64'))/D23\
                                           + (compositions_Ti_family['atomic_radii_2'].astype('float64') * compositions_Ti_family['atomic_radii_4'].astype('float64'))/D24\
                                           + (compositions_Ti_family['atomic_radii_2'].astype('float64') * compositions_Ti_family['atomic_radii_5'].astype('float64'))/D25\
                                           + (compositions_Ti_family['atomic_radii_2'].astype('float64') * compositions_Ti_family['atomic_radii_6'].astype('float64'))/D26\
                                           + (compositions_Ti_family['atomic_radii_2'].astype('float64') * compositions_Ti_family['atomic_radii_7'].astype('float64'))/D27\
                                           + (compositions_Ti_family['atomic_radii_2'].astype('float64') * compositions_Ti_family['atomic_radii_8'].astype('float64'))/D28\
                                           + (compositions_Ti_family['atomic_radii_3'].astype('float64') * compositions_Ti_family['atomic_radii_4'].astype('float64'))/D34\
                                           + (compositions_Ti_family['atomic_radii_3'].astype('float64') * compositions_Ti_family['atomic_radii_5'].astype('float64'))/D35\
                                           + (compositions_Ti_family['atomic_radii_3'].astype('float64') * compositions_Ti_family['atomic_radii_6'].astype('float64'))/D36\
                                           + (compositions_Ti_family['atomic_radii_3'].astype('float64') * compositions_Ti_family['atomic_radii_7'].astype('float64'))/D37\
                                           + (compositions_Ti_family['atomic_radii_3'].astype('float64') * compositions_Ti_family['atomic_radii_8'].astype('float64'))/D38\
                                           + (compositions_Ti_family['atomic_radii_4'].astype('float64') * compositions_Ti_family['atomic_radii_5'].astype('float64'))/D45\
                                           + (compositions_Ti_family['atomic_radii_4'].astype('float64') * compositions_Ti_family['atomic_radii_6'].astype('float64'))/D46\
                                           + (compositions_Ti_family['atomic_radii_4'].astype('float64') * compositions_Ti_family['atomic_radii_7'].astype('float64'))/D47\
                                           + (compositions_Ti_family['atomic_radii_4'].astype('float64') * compositions_Ti_family['atomic_radii_8'].astype('float64'))/D48\
                                           + (compositions_Ti_family['atomic_radii_5'].astype('float64') * compositions_Ti_family['atomic_radii_6'].astype('float64'))/D56\
                                           + (compositions_Ti_family['atomic_radii_5'].astype('float64') * compositions_Ti_family['atomic_radii_7'].astype('float64'))/D57\
                                           + (compositions_Ti_family['atomic_radii_5'].astype('float64') * compositions_Ti_family['atomic_radii_8'].astype('float64'))/D58\
                                           + (compositions_Ti_family['atomic_radii_6'].astype('float64') * compositions_Ti_family['atomic_radii_7'].astype('float64'))/D67\
                                           + (compositions_Ti_family['atomic_radii_6'].astype('float64') * compositions_Ti_family['atomic_radii_8'].astype('float64'))/D68\
                                           + (compositions_Ti_family['atomic_radii_7'].astype('float64') * compositions_Ti_family['atomic_radii_8'].astype('float64'))/D78

compositions_Ti_family['hoe_ac'] =           (compositions_Ti_family['hoe_1'].astype('float64') * compositions_Ti_family['hoe_2'].astype('float64'))/D12\
                                           + (compositions_Ti_family['hoe_1'].astype('float64') * compositions_Ti_family['hoe_3'].astype('float64'))/D13\
                                           + (compositions_Ti_family['hoe_1'].astype('float64') * compositions_Ti_family['hoe_4'].astype('float64'))/D14\
                                           + (compositions_Ti_family['hoe_1'].astype('float64') * compositions_Ti_family['hoe_5'].astype('float64'))/D15\
                                           + (compositions_Ti_family['hoe_1'].astype('float64') * compositions_Ti_family['hoe_6'].astype('float64'))/D16\
                                           + (compositions_Ti_family['hoe_1'].astype('float64') * compositions_Ti_family['hoe_7'].astype('float64'))/D17\
                                           + (compositions_Ti_family['hoe_1'].astype('float64') * compositions_Ti_family['hoe_8'].astype('float64'))/D18\
                                           + (compositions_Ti_family['hoe_2'].astype('float64') * compositions_Ti_family['hoe_3'].astype('float64'))/D23\
                                           + (compositions_Ti_family['hoe_2'].astype('float64') * compositions_Ti_family['hoe_4'].astype('float64'))/D24\
                                           + (compositions_Ti_family['hoe_2'].astype('float64') * compositions_Ti_family['hoe_5'].astype('float64'))/D25\
                                           + (compositions_Ti_family['hoe_2'].astype('float64') * compositions_Ti_family['hoe_6'].astype('float64'))/D26\
                                           + (compositions_Ti_family['hoe_2'].astype('float64') * compositions_Ti_family['hoe_7'].astype('float64'))/D27\
                                           + (compositions_Ti_family['hoe_2'].astype('float64') * compositions_Ti_family['hoe_8'].astype('float64'))/D28\
                                           + (compositions_Ti_family['hoe_3'].astype('float64') * compositions_Ti_family['hoe_4'].astype('float64'))/D34\
                                           + (compositions_Ti_family['hoe_3'].astype('float64') * compositions_Ti_family['hoe_5'].astype('float64'))/D35\
                                           + (compositions_Ti_family['hoe_3'].astype('float64') * compositions_Ti_family['hoe_6'].astype('float64'))/D36\
                                           + (compositions_Ti_family['hoe_3'].astype('float64') * compositions_Ti_family['hoe_7'].astype('float64'))/D37\
                                           + (compositions_Ti_family['hoe_3'].astype('float64') * compositions_Ti_family['hoe_8'].astype('float64'))/D38\
                                           + (compositions_Ti_family['hoe_4'].astype('float64') * compositions_Ti_family['hoe_5'].astype('float64'))/D45\
                                           + (compositions_Ti_family['hoe_4'].astype('float64') * compositions_Ti_family['hoe_6'].astype('float64'))/D46\
                                           + (compositions_Ti_family['hoe_4'].astype('float64') * compositions_Ti_family['hoe_7'].astype('float64'))/D47\
                                           + (compositions_Ti_family['hoe_4'].astype('float64') * compositions_Ti_family['hoe_8'].astype('float64'))/D48\
                                           + (compositions_Ti_family['hoe_5'].astype('float64') * compositions_Ti_family['hoe_6'].astype('float64'))/D56\
                                           + (compositions_Ti_family['hoe_5'].astype('float64') * compositions_Ti_family['hoe_7'].astype('float64'))/D57\
                                           + (compositions_Ti_family['hoe_5'].astype('float64') * compositions_Ti_family['hoe_8'].astype('float64'))/D58\
                                           + (compositions_Ti_family['hoe_6'].astype('float64') * compositions_Ti_family['hoe_7'].astype('float64'))/D67\
                                           + (compositions_Ti_family['hoe_6'].astype('float64') * compositions_Ti_family['hoe_8'].astype('float64'))/D68\
                                           + (compositions_Ti_family['hoe_7'].astype('float64') * compositions_Ti_family['hoe_8'].astype('float64'))/D78

compositions_Ti_family['lue_ac'] =           (compositions_Ti_family['lue_1'].astype('float64') * compositions_Ti_family['lue_2'].astype('float64'))/D12\
                                           + (compositions_Ti_family['lue_1'].astype('float64') * compositions_Ti_family['lue_3'].astype('float64'))/D13\
                                           + (compositions_Ti_family['lue_1'].astype('float64') * compositions_Ti_family['lue_4'].astype('float64'))/D14\
                                           + (compositions_Ti_family['lue_1'].astype('float64') * compositions_Ti_family['lue_5'].astype('float64'))/D15\
                                           + (compositions_Ti_family['lue_1'].astype('float64') * compositions_Ti_family['lue_6'].astype('float64'))/D16\
                                           + (compositions_Ti_family['lue_1'].astype('float64') * compositions_Ti_family['lue_7'].astype('float64'))/D17\
                                           + (compositions_Ti_family['lue_1'].astype('float64') * compositions_Ti_family['lue_8'].astype('float64'))/D18\
                                           + (compositions_Ti_family['lue_2'].astype('float64') * compositions_Ti_family['lue_3'].astype('float64'))/D23\
                                           + (compositions_Ti_family['lue_2'].astype('float64') * compositions_Ti_family['lue_4'].astype('float64'))/D24\
                                           + (compositions_Ti_family['lue_2'].astype('float64') * compositions_Ti_family['lue_5'].astype('float64'))/D25\
                                           + (compositions_Ti_family['lue_2'].astype('float64') * compositions_Ti_family['lue_6'].astype('float64'))/D26\
                                           + (compositions_Ti_family['lue_2'].astype('float64') * compositions_Ti_family['lue_7'].astype('float64'))/D27\
                                           + (compositions_Ti_family['lue_2'].astype('float64') * compositions_Ti_family['lue_8'].astype('float64'))/D28\
                                           + (compositions_Ti_family['lue_3'].astype('float64') * compositions_Ti_family['lue_4'].astype('float64'))/D34\
                                           + (compositions_Ti_family['lue_3'].astype('float64') * compositions_Ti_family['lue_5'].astype('float64'))/D35\
                                           + (compositions_Ti_family['lue_3'].astype('float64') * compositions_Ti_family['lue_6'].astype('float64'))/D36\
                                           + (compositions_Ti_family['lue_3'].astype('float64') * compositions_Ti_family['lue_7'].astype('float64'))/D37\
                                           + (compositions_Ti_family['lue_3'].astype('float64') * compositions_Ti_family['lue_8'].astype('float64'))/D38\
                                           + (compositions_Ti_family['lue_4'].astype('float64') * compositions_Ti_family['lue_5'].astype('float64'))/D45\
                                           + (compositions_Ti_family['lue_4'].astype('float64') * compositions_Ti_family['lue_6'].astype('float64'))/D46\
                                           + (compositions_Ti_family['lue_4'].astype('float64') * compositions_Ti_family['lue_7'].astype('float64'))/D47\
                                           + (compositions_Ti_family['lue_4'].astype('float64') * compositions_Ti_family['lue_8'].astype('float64'))/D48\
                                           + (compositions_Ti_family['lue_5'].astype('float64') * compositions_Ti_family['lue_6'].astype('float64'))/D56\
                                           + (compositions_Ti_family['lue_5'].astype('float64') * compositions_Ti_family['lue_7'].astype('float64'))/D57\
                                           + (compositions_Ti_family['lue_5'].astype('float64') * compositions_Ti_family['lue_8'].astype('float64'))/D58\
                                           + (compositions_Ti_family['lue_6'].astype('float64') * compositions_Ti_family['lue_7'].astype('float64'))/D67\
                                           + (compositions_Ti_family['lue_6'].astype('float64') * compositions_Ti_family['lue_8'].astype('float64'))/D68\
                                           + (compositions_Ti_family['lue_7'].astype('float64') * compositions_Ti_family['lue_8'].astype('float64'))/D78

# %%
#compositions_Ti_family.head
#compositions_Ti_family_0 = compositions_Ti_family.drop(['formula', 'Pb', 'Ca', 'Sr', 'Ba', 'Ti', 'O', 'site1', 'site2', 'site3', 'site4', 'site5', 'site6', 'site7', 'site8'], axis=1)
#compositions_Ti_family_0.hist(layout=(3,4), figsize=(15,30))
#compositions_Ti_family_0.drop(['elenega1', 'elenega2, 'elenega'])
compositions_ac_old_test_structures = compositions_Ti_family.filter(regex=r'_ac*')
compositions_ac_old_test_structures.hist(layout = (3,5), figsize=(10,10));

# %%
os.chdir('/Users/afridshirsekar/Desktop/graphnet scripts/')
compositions_ac_old_test_structures['bandgap'] = compositions_Ti_family['bandgap']
compositions_ac_old_test_structures.to_csv('Compositions_ac_old_test_structures.csv', sep='\t')
# Out:
# <ipython-input-24-c045d2de53da>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   compositions_ac_old_test_structures['bandgap'] = compositions_Ti_family['bandgap']

# %%
print(compositions_ac_old_test_structures['bandgap'])
# Out:
# 0      1.462422
# 1      1.462142
# 2      1.696664
# 3      1.595094
# 4      1.462773
#          ...
# 814    2.951587
# 815    2.943876
# 816    2.943871
# 817    2.935219
# 818    2.949759
# Name: bandgap, Length: 818, dtype: float64

# %%
print(compositions_ac_old_test_structures)
# Out:
#      elenega_ac  eleaff_ac      ionz1_ac      ionz2_ac      ionz3_ac  \
# 0      6.270561   0.132900  1.846621e+06  6.995777e+06  6.593046e+07
# 1      6.270561   0.132900  1.846621e+06  6.995777e+06  6.593046e+07
# 2      6.278165   0.137703  1.846723e+06  6.996539e+06  6.638427e+07
# 3      6.278165   0.137703  1.846723e+06  6.996539e+06  6.638427e+07
# 4      6.270561   0.132900  1.846621e+06  6.995777e+06  6.593046e+07
# ..          ...        ...           ...           ...           ...
# 814    5.369876   0.007298  1.833025e+06  6.895305e+06  1.155383e+08
# 815    5.370058   0.007338  1.833144e+06  6.895784e+06  1.155818e+08
# 816    5.370058   0.007338  1.833144e+06  6.895784e+06  1.155818e+08
# 817    5.370138   0.007355  1.833196e+06  6.895996e+06  1.156011e+08
# 818    5.370320   0.007395  1.833314e+06  6.896474e+06  1.156447e+08
#
#          ionz4_ac      ionz5_ac      ionz6_ac  orb_rad_rs_ac  orb_rad_rp_ac  \
# ...
